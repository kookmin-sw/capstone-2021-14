# %%
import pandas as pd

# %%
df = pd.read_csv('all.csv')

# %%
df_suff = df.sample(frac=1).reset_index(drop=True)

# %%
df_suff.dtypes
# Out:
# 0      float64
# 1      float64
# 2      float64
# 3      float64
# 4      float64
#         ...
# 386    float64
# 387    float64
# 388    float64
# 389    float64
# 390     object
# Length: 391, dtype: object

# %%
df_suff.to_csv("all-shuffle.csv", index=False)

# %%
df.values
# Out:
# array([[315.2393798828125, 131.38780212402344, -25.103200912475586, ...,
#         253.4248046875, 53.43645477294922, 'Egg'],
#        [319.4134521484375, 131.4500732421875, -3.400193452835083, ...,
#         265.3800048828125, 60.56496810913086, 'Egg'],
#        [323.21343994140625, 121.5343246459961, -4.246975898742677, ...,
#         266.87496948242193, 69.78834533691406, 'Egg'],
#        ...,
#        [318.6099548339844, 135.43330383300778, -16.516231536865234, ...,
#         263.98336791992193, 63.50058364868164, 'RTriangle'],
#        [318.9456787109375, 123.7164077758789, -13.022541999816895, ...,
#         255.61387634277344, 58.81241226196289, 'RTriangle'],
#        [322.3459167480469, 127.5517807006836, -21.391891479492188, ...,
#         250.37432861328125, 63.87670135498047, 'RTriangle']], dtype=object)

# %%
df = pd.read_csv('all-shuffle.csv')

# %%
df
# Out:
#               0           1          2           3           4          5  \
# 0    319.300629  124.876991  -9.204401  153.186081  185.276855  29.706360
# 1    318.793549  124.719627  -0.511394  163.816864  184.525696  42.988605
# 2    318.945679  123.716408 -13.022542  164.274902  178.805008  33.600101
# 3    316.537140  117.673401  -5.780018  159.503738  185.037994  37.016182
# 4    322.687195  125.692596 -23.956440  160.397308  172.556839  20.003565
# ..          ...         ...        ...         ...         ...        ...
# 399  319.413452  131.450073  -3.400193  164.606247  189.060669  38.881615
# 400  321.660492  137.216125  -1.396778  152.113968  196.400970  33.659912
# 401  317.121094  113.578697 -14.547271  167.480820  174.955093  30.609055
# 402  317.741791  122.972984 -15.717838  148.674088  176.779922  25.161165
# 403  322.178314  117.419502   7.706770  155.307297  187.437302  36.563293
#
#               6           7          8           9  ...         381  \
# ...

# %%
df_egg = pd.read_csv('EggSet-del-Z.csv')
df_circle = pd.read_csv('CircleSet-del-Z.csv')
df_rect = pd.read_csv('RectSet-del-Z.csv')
df_rtriangle = pd.read_csv('RTriangleSet-del-Z.csv')

# %%
# z좌표 제거
df1 = df.drop(columns=["{}".format(i) for i in range(2, 390, 3)])
df1.columns = ["{}".format(i) for i in range(261)]

# %%
df1
# Out:
#               0           1           2           3           4           5  \
# 0    315.239380  131.387802  168.357651  181.003250  263.102020  406.322449
# 1    319.413452  131.450073  164.606247  189.060669  269.262512  391.032715
# 2    323.213440  121.534325  148.416946  179.645905  262.039856  407.202515
# 3    315.606232  116.235092  169.493423  184.386414  267.400970  407.543915
# 4    315.399200  119.599144  170.786530  183.642410  257.886353  409.809082
# ..          ...         ...         ...         ...         ...         ...
# 96   319.523560  131.561142  158.096634  177.810150  267.798004  387.371307
# 97   319.098389  119.421631  157.074203  177.213135  265.751282  405.973389
# 98   318.825592  127.232323  156.379196  180.986267  263.464874  401.945709
# 99   320.404083  107.523643  157.485855  178.429459  263.316528  434.623138
# 100  315.908783  137.585266  170.312271  186.853012  253.755524  408.466217
#
# ...

# %%
df1.to_csv("EggSet-del-Z.csv", index=False)

# %%
df1.to_csv("allshuffle-deleteZ.csv", index=False)

# %%
# concat을 이용하여 합치기
df_all = pd.concat([df_egg, df_circle, df_rect, df_rtriangle])
# df_all파일을 Danfo.js의 load할 때 사용
df_all_real = df_all.reset_index()

# %%
df = pd.read_csv("all-shuffle-deleteZ.csv")

# %%
df1 = df[["{}".format(i) for i in range(260)]]

# %%
df1
# Out:
#               0           1           2           3           4           5  \
# 0    319.300629  124.876991  153.186081  185.276855  259.967285  410.240234
# 1    318.793549  124.719627  163.816864  184.525696  268.918488  385.833984
# 2    318.945679  123.716408  164.274902  178.805008  265.851929  391.724518
# 3    316.537140  117.673401  159.503738  185.037994  262.726257  422.701202
# 4    322.687195  125.692596  160.397308  172.556839  265.222473  402.140930
# ..          ...         ...         ...         ...         ...         ...
# 399  319.413452  131.450073  164.606247  189.060669  269.262512  391.032715
# 400  321.660492  137.216125  152.113968  196.400970  260.414917  395.466187
# 401  317.121094  113.578697  167.480820  174.955093  266.364502  418.705078
# 402  317.741791  122.972984  148.674088  176.779922  267.801483  398.901337
# 403  322.178314  117.419502  155.307297  187.437302  268.367645  416.956818
#
# ...

# %%
# Out:
#               0           1           2           3           4           5  \
# 0    319.300629  124.876991  153.186081  185.276855  259.967285  410.240234
# 1    318.793549  124.719627  163.816864  184.525696  268.918488  385.833984
# 2    318.945679  123.716408  164.274902  178.805008  265.851929  391.724518
# 3    316.537140  117.673401  159.503738  185.037994  262.726257  422.701202
# 4    322.687195  125.692596  160.397308  172.556839  265.222473  402.140930
# ..          ...         ...         ...         ...         ...         ...
# 399  319.413452  131.450073  164.606247  189.060669  269.262512  391.032715
# 400  321.660492  137.216125  152.113968  196.400970  260.414917  395.466187
# 401  317.121094  113.578697  167.480820  174.955093  266.364502  418.705078
# 402  317.741791  122.972984  148.674088  176.779922  267.801483  398.901337
# 403  322.178314  117.419502  155.307297  187.437302  268.367645  416.956818
#
# ...

# %%
normalization_df = (df1 - df1.mean())/df1.std()

# %%
normalization_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.213415 -0.029065 -0.604029  0.222119 -0.535054  0.407096 -0.650137
# 1    0.080005 -0.051035  0.513603  0.109997  1.539854 -1.778150  0.795669
# 2    0.120029 -0.191098  0.561757 -0.743904  0.829019 -1.250733  0.753125
# 3   -0.513643 -1.034783  0.060157  0.186465  0.104482  1.522805  0.040106
# 4    1.104400  0.084805  0.154099 -1.676540  0.683110 -0.318086  0.194611
# ..        ...       ...       ...       ...       ...       ...       ...
# 399  0.243098  0.888626  0.596592  0.786912  1.619600 -1.312675  0.702070
# 400  0.834281  1.693644 -0.716742  1.882565 -0.431292 -0.915718 -0.951834
# 401 -0.360008 -1.606459  0.898801 -1.318563  0.947835  1.165007  0.909017
# 402 -0.196706 -0.294890 -1.078382 -1.046179  1.280930 -0.608147 -0.863560
# 403  0.970517 -1.070231 -0.381022  0.544599  1.412168  1.008474 -0.492422
#
#             7         8         9  ...       250       251       252  \
# ...

# %%
normalization_df["260"] = df["260"]

# %%
normalization_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.213415 -0.029065 -0.604029  0.222119 -0.535054  0.407096 -0.650137
# 1    0.080005 -0.051035  0.513603  0.109997  1.539854 -1.778150  0.795669
# 2    0.120029 -0.191098  0.561757 -0.743904  0.829019 -1.250733  0.753125
# 3   -0.513643 -1.034783  0.060157  0.186465  0.104482  1.522805  0.040106
# 4    1.104400  0.084805  0.154099 -1.676540  0.683110 -0.318086  0.194611
# ..        ...       ...       ...       ...       ...       ...       ...
# 399  0.243098  0.888626  0.596592  0.786912  1.619600 -1.312675  0.702070
# 400  0.834281  1.693644 -0.716742  1.882565 -0.431292 -0.915718 -0.951834
# 401 -0.360008 -1.606459  0.898801 -1.318563  0.947835  1.165007  0.909017
# 402 -0.196706 -0.294890 -1.078382 -1.046179  1.280930 -0.608147 -0.863560
# 403  0.970517 -1.070231 -0.381022  0.544599  1.412168  1.008474 -0.492422
#
#             7         8         9  ...       251       252       253  \
# ...

# %%
normalization_df.to_csv("norm-all-data.csv", index=False)
